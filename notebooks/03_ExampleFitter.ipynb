# %%
import sys
sys.path.append('../../FourVector')
sys.path.append('../project')

from FourVector import FourVector
from ThreeVector import ThreeVector

from FutureColliderTools import SmearVertex, GetCorrectedMass, GetMissingMass2, GetQ2
from FutureColliderDataLoader import LoadData_KMuNu, LoadData_DsMuNu
from FutureColliderVariables import *
from FutureColliderFitter import FutureFitter

import numpy as np
import ROOT

ROOT.enableJSVis()
ROOT.gStyle.SetOptStat(0)
# Out:
# Welcome to JupyROOT 6.08/02

# %% [markdown]
# # Perform and plot a $B_s \rightarrow D_s^- \mu^+ \nu_{\mu}$ fit at LHCb resolution
#
# ## In the plot the lines are before Beeston Barlow, the points are after

# %%
Fitter = FutureFitter("../output/Data_Histograms_1.0_LHCb.root", "MCORR_Data_DsMuNu",  "../output/Source_Histograms_DsMu_1.0_LHCb_Merged.root")
Fitter.Fit()

c1 = ROOT.TCanvas("c1", "c1", 1024,768)

Fitter.Plot(c1)

c1.Draw()
# Out:
#  **********
#  **    1 **SET PRINT           0
#  **********
#  **********
#  **    2 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac0        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      2 frac1        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      3 frac2        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      4 frac3        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      5 frac4        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#  **********
#  **    3 **SET ERR         0.5
#  **********
#  **********
#  **    4 **SET PRINT           0
#  **********
#  **********
#  **    5 **SET STR           1
#  **********
#  **********
#  **    6 **MIGRAD        1625        0.01
#  **********
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  FCN=-6.25011e+06 FROM MIGRAD    STATUS=CONVERGED     296 CALLS         297 TOTAL
#                      EDM=9.02119e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.3 per cent
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac0        2.90868e-02   2.32103e-03  -3.08917e-06  -7.72109e-02
#    2  frac1        4.36721e-02   4.09736e-03  -3.66036e-05  -9.42787e-02
#    3  frac2        5.81412e-01   2.18449e-02  -5.88998e-05  -9.84714e-02
#    4  frac3        5.76034e-02   9.24276e-03   3.41979e-05  -7.69267e-02
#    5  frac4        2.88222e-01   1.74075e-02   8.22216e-05   4.23114e-02
#                                ERR DEF= 0.5
# +------------------+----------+-----------+
# |     Template     | Fraction | Error [%] |
# +------------------+----------+-----------+
# |   13774000_Tau   |  0.029   |    7.97   |
# | Combinatorial_Ds |  0.043   |    9.38   |
# | 13774000_Dsstar  |  0.581   |    3.75   |
# |  13774000_Ds01   |  0.057   |   16.04   |
# |   13774000_Ds    |  0.288   |    6.03   |
# +------------------+----------+-----------+
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# <div id="root_plot_1"
#      style="width: 1020px; height: 740px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":2062.49996740371,"fY1":-2733.28145364533,"fX2":6437.50003259629,"fY2":24599.5314536453,"fXtoAbsPixelk":-480.85707809222,"fXtoPixelk":-480.85707809222,"fXtoPixel":0.233142853668758,"fYtoAbsPixelk":666.000045589256,"fYtoPixelk":666.000045589256,"fYtoPixel":-0.0270736862140748,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1020,"fVtoAbsPixelk":740.00005,"fVtoPixelk":740,"fVtoPixel":-740,"fAbsPixeltoXk":2062.49996740371,"fPixeltoXk":2062.49996740371,"fPixeltoX":4.28921575018881,"fAbsPixeltoYk":24599.5314536453,"fPixeltoYk":-2733.28145364533,"fPixeltoY":-36.9362336585009,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":2500,"fUymin":0,"fUxmax":6000,"fUymax":21866.25,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":2500,"fY1":0,"fX2":6000,"fY2":21866.25,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50332168,"fName":"MCORR_Data_DsMuNu","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":2500,"fXmax":6000,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":690000,"fTsumw":690000,"fTsumw2":690000,"fTsumwx":3419076940.60733,"fTsumwx2":17150618437111.5,"fMaximum":-1111,"fMinimum":0,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":0,"fBuffer":[],"fBinStatErrOpt":0,"fArray":[0,7,10,18,10,27,53,50,88,54,72,104,150,155,161,216,316,320,404,386,415,528,556,636,785,780,846,977,1038,1219,1351,1365,1706,1640,1830,2017,2285,2468,2442,2718,3027,3075,3262,3426,3701,4119,4560,4581,5108,5144,5593,5876,6398,6931,7352,8009,8594,9104,9430,10202,10524,11495,12294,12589,13268,13963,14713,15719,16341,17133,17811,18521,19432,19628,2079 ...

# %% [markdown]
# # Perform and plot a $B_s \rightarrow K^- \mu^+ \nu_{\mu}$ fit at LHCb resolution
#
# ## In the plot the lines are before Beeston Barlow, the points are after

# %%
Fitter = FutureFitter("../output/Data_Histograms_1.0_LHCb.root", "MCORR_Data_KMuNu",  "../output/Source_Histograms_KMu_1.0_LHCb_Merged.root")
Fitter.Fit()

c1 = ROOT.TCanvas("c1", "c1", 1024,768)

Fitter.Plot(c1)

c1.Draw()
# Out:
#  **********
#  **    7 **SET PRINT           0
#  **********
#  **********
#  **    8 **SET NOGRAD
#  **********
#  PARAMETER DEFINITIONS:
#     NO.   NAME         VALUE      STEP SIZE      LIMITS
#      1 frac0        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      2 frac1        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      3 frac2        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      4 frac3        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#      5 frac4        2.00000e-01  1.00000e-02    0.00000e+00  1.00000e+01
#  **********
#  **    9 **SET ERR         0.5
#  **********
#  **********
#  **   10 **SET PRINT           0
#  **********
#  **********
#  **   11 **SET STR           1
#  **********
#  **********
#  **   12 **MIGRAD        1625        0.01
#  **********
#  MACHINE ACCURACY LIMITS FURTHER IMPROVEMENT.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MACHINE ACCURACY LIMITS FURTHER IMPROVEMENT.
#  MIGRAD MINIMIZATION HAS CONVERGED.
#  MIGRAD WILL VERIFY CONVERGENCE AND ERROR MATRIX.
#  MIGRAD TERMINATED WITHOUT CONVERGENCE.
#  FCN=-1.49785e+06 FROM MIGRAD    STATUS=FAILED        439 CALLS         440 TOTAL
#                      EDM=0.000128911    STRATEGY= 1      ERR MATRIX APPROXIMATE
#   EXT PARAMETER                APPROXIMATE        STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  frac0        8.42978e-02   2.00562e-02   3.56729e-03   7.04937e-01
#    2  frac1        1.58143e-01   6.27556e-03   1.82717e-03   1.08638e+00
#    3  frac2        5.62582e-01   3.42007e-02   1.38695e-03   2.76715e+00
#    4  frac3        1.16173e-01   1.87879e-02   2.74696e-03   1.16061e+00
#    5  frac4        7.88202e-02   4.74309e-03   2.34421e-03   1.42260e-01
#                                ERR DEF= 0.5
# +------------------+----------+-----------+
# |     Template     | Fraction | Error [%] |
# +------------------+----------+-----------+
# |     12513010     |  0.084   |   23.79   |
# |     13512010     |  0.158   |    3.96   |
# | 13774000_DsX_Tau |  0.562   |    6.07   |
# |  13774000_Ds01   |  0.116   |   16.17   |
# | Combinatorial_K  |  0.078   |    6.01   |
# +------------------+----------+-----------+
# Warning in <TFractionFitter::Fit>: Abnormal termination of minimization.
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_2"
#      style="width: 1020px; height: 740px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
#        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":2062.49996740371,"fY1":-257.643769195956,"fX2":6437.50003259629,"fY2":2318.79376919596,"fXtoAbsPixelk":-480.85707809222,"fXtoPixelk":-480.85707809222,"fXtoPixel":0.233142853668758,"fYtoAbsPixelk":666.000045589256,"fYtoPixelk":666.000045589256,"fYtoPixel":-0.287218296183447,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1020,"fVtoAbsPixelk":740.00005,"fVtoPixelk":740,"fVtoPixel":-740,"fAbsPixeltoXk":2062.49996740371,"fPixeltoXk":2062.49996740371,"fPixeltoX":4.28921575018881,"fAbsPixeltoYk":2318.79376919596,"fPixeltoYk":-257.643769195956,"fPixeltoY":-3.48167234917826,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":2500,"fUymin":0,"fUxmax":6000,"fUymax":2061.15,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":2500,"fY1":0,"fX2":6000,"fY2":2061.15,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50332168,"fName":"MCORR_Data_KMuNu","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":2500,"fXmax":6000,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":125000,"fTsumw":125000,"fTsumw2":125000,"fTsumwx":506573153.924157,"fTsumwx2":2144391532214.01,"fMaximum":-1111,"fMinimum":0,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":0,"fBuffer":[],"fBinStatErrOpt":0,"fArray":[0,712,786,875,908,954,958,965,998,1124,1117,1132,1272,1248,1290,1312,1400,1412,1374,1457,1515,1496,1561,1551,1622,1682,1707,1690,1763,1824,1826,1820,1788,1878,1829,1835,1916,1865,1953,1888,1963,1882,1874,1802,1840,1828,1791,1830,1754,1778,1694,1680,1571,1581,1546,1474,1469,1415,1343,1293,1324,1296,1243,1302,1151,1104,1141,1094,1114,1046,1019,1067,984 ...
